# %% [markdown]
# let's try turtle stuff

# %%
# from turtle import * # regular turtle graphics doesn't draw in notebook
from jupyturtle import * # so someone made this one

# intro turtle code from https://docs.python.org/3/library/turtle.html#tutorial

make_turtle()
set_fill_color('black')
begin_fill()
set_color('red')
forward(60)
left(120)
set_color('green')
forward(60)
left(120)
set_color('blue')
forward(60)
end_fill()
left(120)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <polygon fill="black" points="150,75 210,75 180,23 150,75" />
#
# <path stroke="red" stroke-width="2" d="M 150,75 210,75" />'
#
# <path stroke="green" stroke-width="2" d="M 210,75 180,23" />'
#
# <path stroke="blue" stroke-width="2" d="M 180,23 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# now let's try something else

# %%
make_turtle(delay=0.5)
set_fill_color('red')
begin_fill()
set_color('pink')
forward(60)
left(120)
set_color('purple')
forward(60)
left(120)
set_color('turquoise')
forward(60)
end_fill()
left(120)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <polygon fill="red" points="150,75 210,75 180,23 150,75" />
#
# <path stroke="pink" stroke-width="2" d="M 150,75 210,75" />'
#
# <path stroke="purple" stroke-width="2" d="M 210,75 180,23" />'
#
# <path stroke="turquoise" stroke-width="2" d="M 180,23 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
