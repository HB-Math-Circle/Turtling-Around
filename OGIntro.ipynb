# %%
from turtle import *
clearscreen()
color('red')
# fillcolor('yellow')
begin_fill()
forward(60)
left(120)
color('green')
forward(60)
left(120)
color('blue', 'yellow')
forward(60)
end_fill()
left(120)
