# %% [markdown]
# let's try turtle stuff

# %%
# from turtle import * # regular turtle graphics doesn't draw in notebook
from jupyturtle import * # so someone made this one

# intro turtle code from https://docs.python.org/3/library/turtle.html#tutorial

make_turtle()
set_color('pink')
forward(60)
left(120)
set_color('purple')
forward(60)
left(120)
set_color('turquoise')
forward(60)
left(120)
right(53)
forward(27)
set_color('red')
left(34)
set_color('orange')
right(111)
forward(27)
set_color('yellow')
left(120)
forward(27)
set_color('green')
right(111)
forward(27)
set_color('turquoise')
left(230)
forward(27)
set_color('blue')
right(23)
forward(27)
set_color('indigo')
left(99)
forward(27)
set_color( 'purple')
right(99)
forward(27)
set_color('magenta')
left(99)
forward(27)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="pink" stroke-width="2" d="M 150,75 210,75" />'
#
# <path stroke="purple" stroke-width="2" d="M 210,75 180,23" />'
#
# <path stroke="turquoise" stroke-width="2" d="M 180,23 150,75 166.2,96.6" />'
#
# <path stroke="orange" stroke-width="2" d="M 166.2,96.6 148.9,117.2" />'
#
# <path stroke="yellow" stroke-width="2" d="M 148.9,117.2 175.5,121.9" />'
#
# <path stroke="green" stroke-width="2" d="M 175.5,121.9 161.6,145.1" />'
#
# <path stroke="turquoise" stroke-width="2" d="M 161.6,145.1 152.8,119.5" />'
#
# <path stroke="blue" stroke-width="2" d="M 152.8,119.5 154.7,92.6" />'
#
# <path stroke="indigo" stroke-width="2" d="M 154.7,92.6 127.8,95" />'
#
# <path stroke="purple" stroke-width="2" d="M 127.8,95 129.7,68" />'
#
# <path stroke="magenta" stroke-width="2" d="M 129.7,68 102.8,70.4" />'
#
# ...

# %% [markdown]
# now let's try something else

# %%
make_turtle(delay=2)
set_fill_color('red')
begin_fill()
set_color('pink')
forward(60)
left(120)
set_color('purple')
forward(60)
left(120)
set_color('turquoise')
forward(60)
end_fill()
left(120)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <polygon fill="red" points="150,75 210,75 180,23 150,75" />
#
# <path stroke="pink" stroke-width="2" d="M 150,75 210,75" />'
#
# <path stroke="purple" stroke-width="2" d="M 210,75 180,23" />'
#
# <path stroke="turquoise" stroke-width="2" d="M 180,23 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
